# %% [markdown]
# # ResNet
# - ResNet에서 정보가 흘러가는 것을 개선하기 위해, DenseNet에서는 ResNet과는 조금 다른 연결 패턴 제안
# - 이전 레이어의 모든 정보를 이후의 레이어의 input으로 받아오는 방법 사용
# - Xl = Hl(X l-1)+X l-1
# - 이전 레이어의 output을 다음 레이어의 output과 합해서 더한다.
# - 정보들이 이후의 레이어들로 온전히 흘러가는 것을 방해할 수 있다는 약점 존재
