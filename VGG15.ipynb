# %%
from keras.applications import vgg16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import vgg16
from IPython.display import display # 이미지 출력 함수
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /workspace/DeepLearningStudy/VGG15.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6577776f726c64222c2273657474696e6773223a7b22686f7374223a227373683a2f2f3139322e3136382e302e323134227d7d/workspace/DeepLearningStudy/VGG15.ipynb#ch0000000vscode-remote?line=0'>1</a> from keras.applications import vgg16
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6577776f726c64222c2273657474696e6773223a7b22686f7374223a227373683a2f2f3139322e3136382e302e323134227d7d/workspace/DeepLearningStudy/VGG15.ipynb#ch0000000vscode-remote?line=1'>2</a> from keras.preprocessing.image import load_img
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6577776f726c64222c2273657474696e6773223a7b22686f7374223a227373683a2f2f3139322e3136382e302e323134227d7d/workspace/DeepLearningStudy/VGG15.ipynb#ch0000000vscode-remote?line=2'>3</a> from keras.preprocessing.image import img_to_array
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6e6577776f726c64222c2273657474696e6773223a7b22686f7374223a227373683a2f2f3139322e3136382e302e323134227d7d/workspace/DeepLearningStudy/VGG15.ipynb#ch0000000vscode-remote?line=3'>4</a> from keras.preprocessing.image import vgg16
#
# ImportError: cannot import name 'load_img' from 'keras.preprocessing.image' (/home/szjung/.local/lib/python3.8/site-packages/keras/preprocessing/image.py)

# %%
$A = Q \lambda Q^T$
# Out:
#   Input In [3]
#     $A = Q \lambda Q^T$
#     ^
# SyntaxError: invalid syntax
